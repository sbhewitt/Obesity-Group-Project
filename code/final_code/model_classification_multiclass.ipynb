# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, RandomForestRegressor, ExtraTreesRegressor, BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, VotingClassifier, GradientBoostingRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

np.random.seed(42)

# %%
df = pd.read_csv('../../data/survey_clean_multiclass.csv')
df.head()
# Out:
#     Age  Height  Weight  fam_hx_overweight  high_cal_foods  vegetables  \
# 0  21.0    1.62    64.0                  1               0         2.0
# 1  21.0    1.52    56.0                  1               0         3.0
# 2  23.0    1.80    77.0                  1               0         2.0
# 3  27.0    1.80    87.0                  0               0         3.0
# 4  22.0    1.78    89.8                  0               0         2.0
#
#    main_meals  smoke  H2O  monitor_cals  ...  food_bw_meals_Frequently  \
# 0         3.0      0  2.0             0  ...                         0
# 1         3.0      1  3.0             1  ...                         0
# 2         3.0      0  2.0             0  ...                         0
# 3         3.0      0  2.0             0  ...                         0
# 4         1.0      0  2.0             0  ...                         0
#
#    food_bw_meals_Sometimes  food_bw_meals_no  alcohol_Frequently  \
# ...

# %%
X = df.drop(columns = ['Weight', 'obesity'])
y = df['obesity']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, stratify = y)

# %%
logreg = LogisticRegression(max_iter = 10000)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
print(f'Train: {logreg.score(X_train, y_train)}')
print(f'Test: {logreg.score(X_test, y_test)}')
# Out:
# Train: 0.6626658243840808
# Test: 0.6553030303030303

# %%
predslog = logreg.predict(X_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, predslog, 
                                        cmap = 'magma',
                                       )
plt.title('Obesity Logistic Regression')

plt.tight_layout()
plt.savefig('../../images/logreg_complex_cmatrix');

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
print(f'Train: {rf.score(X_train, y_train)}')
print(f'Test: {rf.score(X_test, y_test)}')
# Out:
# Train: 1.0
# Test: 0.8560606060606061

# %%
predsrf = rf.predict(X_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, predsrf, 
                                        cmap = 'magma',
                                       )
plt.title('Obesity RandomForest')

plt.tight_layout()
plt.savefig('../../images/rf_complex_cmatrix');

# %%
ada = AdaBoostClassifier()
ada.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
print(f'Train: {ada.score(X_train, y_train)}')
print(f'Test: {ada.score(X_test, y_test)}')
# Out:
# Train: 0.6708780795957043
# Test: 0.6439393939393939

# %%
predsada = ada.predict(X_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, predsada, 
                                        cmap = 'magma',
                                       )
plt.title('Obesity AdaBoost')

plt.tight_layout()
plt.savefig('../../images/ada_complex_cmatrix');

# %%
gr = GradientBoostingClassifier()
gr.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
print(f'Train: {gr.score(X_train, y_train)}')
print(f'Test: {gr.score(X_test, y_test)}')
# Out:
# Train: 0.9437776373973468
# Test: 0.8333333333333334

# %%
predsgr = gr.predict(X_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, predsgr, 
                                        cmap = 'magma',
                                       )
plt.title('Obesity GradientBoost')

plt.tight_layout()
plt.savefig('../../images/gr_complex_cmatrix');

# %% [markdown]
# ________________________________
#
# ## Feature Engineering

# %%
X = df.drop(columns = ['Weight', 'obesity'])
y = df['obesity']

# %%
X['Height^2'] = X['Height'] ** 2
X['Age^2'] = X['Age'] ** 2
X['physical_activity^2'] = X['physical_activity'] ** 2

# %%
#Polynomial from Ryan (Did not end up improving values)
# Create polynomial features
#poly = PolynomialFeatures(2, interaction_only = True, include_bias = False)
#array_poly = poly.fit_transform(df[['Height', 'high_cal_foods', 'vegetables', 'main_meals', 'H2O']])

# Polynomial Feature Dataframe
#df_poly = pd.DataFrame(array_poly, columns = poly.get_feature_names_out(['Height', 'high_cal_foods', 'vegetables', 'main_meals', 'H2O']))

# Merge Polynomial Features df
#df = df.merge(df_poly.iloc[:,4:], left_index = True, right_index = True)

# Create height^2 column
#df['h2'] = df['Height'] ** 2

#X = df.drop(columns = ['obesity', 'Weight'])
#y = df['obesity']

# %%
df.head()
# Out:
#     Age  Height  Weight  fam_hx_overweight  high_cal_foods  vegetables  \
# 0  21.0    1.62    64.0                  1               0         2.0
# 1  21.0    1.52    56.0                  1               0         3.0
# 2  23.0    1.80    77.0                  1               0         2.0
# 3  27.0    1.80    87.0                  0               0         3.0
# 4  22.0    1.78    89.8                  0               0         2.0
#
#    main_meals  smoke  H2O  monitor_cals  ...  food_bw_meals_Frequently  \
# 0         3.0      0  2.0             0  ...                         0
# 1         3.0      1  3.0             1  ...                         0
# 2         3.0      0  2.0             0  ...                         0
# 3         3.0      0  2.0             0  ...                         0
# 4         1.0      0  2.0             0  ...                         0
#
#    food_bw_meals_Sometimes  food_bw_meals_no  alcohol_Frequently  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, stratify = y)

# %%
gr2 = GradientBoostingClassifier()
gr2.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
print(f'Train: {gr2.score(X_train, y_train)}')
print(f'Test: {gr2.score(X_test, y_test)}')
# Out:
# Train: 0.9437776373973468
# Test: 0.8371212121212122

# %%
predsgr2 = gr2.predict(X_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, predsgr2, 
                                        cmap = 'magma',
                                       )
plt.title('Obesity GradientBoost')

plt.tight_layout()
plt.savefig('../../images/gr_complex_poly_cmatrix');

# %%
plt.figure(figsize = (15,8))
test1 = pd.DataFrame(gr2.feature_importances_, index = X.columns, columns = ['value'])
test1 = test1.sort_values(by = 'value')

plt.barh(y = test1.index, width = test1['value'])
plt.title("Feature Importance")
plt.ylabel("Features")
plt.tight_layout();
plt.savefig('../../images/gr_complex_poly_feature_importance');

# %%
rf2 = RandomForestClassifier()
rf2.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
print(f'Train: {rf2.score(X_train, y_train)}')
print(f'Test: {rf2.score(X_test, y_test)}')
# Out:
# Train: 1.0
# Test: 0.884469696969697

# %%
predsrf2 = rf2.predict(X_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, predsrf2, 
                                        cmap = 'magma',
                                       )
plt.title('Obesity RandomForest')

plt.tight_layout()
plt.savefig('../../images/rf_complex_poly_cmatrix');

# %%
plt.figure(figsize = (15,8))
test2 = pd.DataFrame(rf2.feature_importances_, index = X.columns, columns = ['value'])
test2 = test2.sort_values(by = 'value')

plt.barh(y = test2.index, width = test1['value'])
plt.title("Feature Importance")
plt.ylabel("Features")
plt.tight_layout();
plt.savefig('../../images/rf_complex_poly_feature_importance');

# %%
ada2 = AdaBoostClassifier()
ada2.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
print(f'Train: {ada2.score(X_train, y_train)}')
print(f'Test: {ada2.score(X_test, y_test)}')
# Out:
# Train: 0.6708780795957043
# Test: 0.6439393939393939

# %%
predsada2 = ada2.predict(X_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, predsada2, 
                                        cmap = 'magma',
                                       )
plt.title('Obesity AdaBoost')

plt.tight_layout()
plt.savefig('../../images/ada_complex_poly_cmatrix');

# %%
plt.figure(figsize = (15,8))
test2 = pd.DataFrame(ada2.feature_importances_, index = X.columns, columns = ['value'])
test2 = test2.sort_values(by = 'value')

plt.barh(y = test2.index, width = test1['value'])
plt.title("Feature Importance")
plt.ylabel("Features")
plt.tight_layout();
plt.savefig('../../images/ada_complex_poly_feature_importance');
